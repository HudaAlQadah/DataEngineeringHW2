# %%
# !pip install -U apache-airflow
import datetime as dt
from datetime import timedelta
from airflow import DAG
from airflow.operators.bash_operator import BashOperator
from airflow.operators.python_operator import PythonOperator
# Out:
# Collecting apache-airflow
#   Downloading apache_airflow-2.3.2-py3-none-any.whl (5.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.2/5.2 MB 1.4 MB/s eta 0:00:0000:0100:010m
# Collecting flask-wtf<0.15,>=0.14.3
#   Downloading Flask_WTF-0.14.3-py2.py3-none-any.whl (13 kB)
# Collecting pathspec~=0.9.0
#   Downloading pathspec-0.9.0-py2.py3-none-any.whl (31 kB)
# Collecting pluggy>=1.0
#   Downloading pluggy-1.0.0-py2.py3-none-any.whl (13 kB)
# Collecting sqlalchemy-jsonfield>=1.0
#   Downloading SQLAlchemy_JSONField-1.0.0-py3-none-any.whl (10 kB)
# Collecting markdown>=3.0
#   Downloading Markdown-3.3.7-py3-none-any.whl (97 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.8/97.8 kB 638.9 kB/s eta 0:00:00a 0:00:01
# Collecting gunicorn>=20.1.0
#   Downloading gunicorn-20.1.0-py3-none-any.whl (79 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 696.3 kB/s eta 0:00:00 0:00:01
# Collecting argcomplete>=1.10
#   Downloading argcomplete-2.0.0-py2.py3-none-any.whl (37 kB)
# Collecting attrs<21.0,>=20.0
#   Downloading attrs-20.3.0-py2.py3-none-any.whl (49 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.3/49.3 kB 846.9 kB/s eta 0:00:00 0:00:01
# Collecting tenacity>=6.2.0
#   Downloading tenacity-8.0.1-py3-none-any.whl (24 kB)
# Collecting lockfile>=0.12.2
#   Downloading lockfile-0.12.2-py2.py3-none-any.whl (13 kB)
# Collecting flask<2.0,>=1.1.0
#   Downloading Flask-1.1.4-py2.py3-none-any.whl (94 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.6/94.6 kB 459.2 kB/s eta 0:00:00 0:00:01
# Requirement already satisfied: alembic<2.0,>=1.5.1 in /opt/conda/lib/python3.9/site-packages (from apache-airflow) (1.7.7)
# Requirement already satisfied: jsonschema<5.0,>=3.2.0 in /opt/conda/lib/python3.9/site-packages (from apache-airflow) (4.5.1)
# Collecting marshmallow-oneofschema>=2.0.1
#   Downloading marshmallow_oneofschema-3.0.1-py2.py3-none-any.whl (5.8 kB)
# Collecting apache-airflow-providers-sqlite
#   Downloading apache_airflow_providers_sqlite-2.1.3-py3-none-any.whl (16 kB)
# Collecting termcolor>=1.1.0
#   Downloading termcolor-1.1.0.tar.gz (3.9 kB)
#   Preparing metadata (setup.py) ... done
# Collecting tabulate>=0.7.5
#   Downloading tabulate-0.8.9-py3-none-any.whl (25 kB)
# Collecting werkzeug>=1.0.1,~=1.0
#   Downloading Werkzeug-1.0.1-py2.py3-none-any.whl (298 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 298.6/298.6 kB 2.2 MB/s eta 0:00:00a 0:00:01
# Collecting python-slugify>=5.0
#   Downloading python_slugify-6.1.2-py2.py3-none-any.whl (9.4 kB)
# Collecting apache-airflow-providers-imap
#   Downloading apache_airflow_providers_imap-2.2.3-py3-none-any.whl (16 kB)
# Requirement already satisfied: packaging>=14.0 in /opt/conda/lib/python3.9/site-packages (from apache-airflow) (21.3)
# Collecting typing-extensions>=3.7.4
#   Downloading typing_extensions-4.2.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: python-dateutil>=2.3 in /opt/conda/lib/python3.9/site-packages (from apache-airflow) (2.8.2)
# Requirement already satisfied: cryptography>=0.9.3 in /opt/conda/lib/python3.9/site-packages (from apache-airflow) (37.0.2)
# Collecting croniter>=0.3.17
#   Downloading croniter-1.3.5-py2.py3-none-any.whl (17 kB)
# Collecting dill>=0.2.2
#   Downloading dill-0.3.5.1-py2.py3-none-any.whl (95 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 95.8/95.8 kB 359.3 kB/s eta 0:00:00:--:--
# Collecting sqlalchemy<1.4.10,>=1.4
#   Downloading SQLAlchemy-1.4.9-cp39-cp39-manylinux2014_x86_64.whl (1.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 1.2 MB/s eta 0:00:0000:0100:010m
# Requirement already satisfied: pygments>=2.0.1 in /opt/conda/lib/python3.9/site-packages (from apache-airflow) (2.12.0)
# Collecting httpx
#   Downloading httpx-0.23.0-py3-none-any.whl (84 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.8/84.8 kB 6.8 MB/s eta 0:00:00
# Collecting apache-airflow-providers-http
#   Downloading apache_airflow_providers_http-2.1.2-py3-none-any.whl (21 kB)
# Collecting apache-airflow-providers-ftp
#   Downloading apache_airflow_providers_ftp-2.1.2-py3-none-any.whl (15 kB)
# Collecting jinja2<3.1,>=2.10.1
#   Downloading Jinja2-3.0.3-py3-none-any.whl (133 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.6/133.6 kB 479.5 kB/s eta 0:00:0000:0100:01
# Collecting itsdangerous<2.0,>=1.1.0
#   Downloading itsdangerous-1.1.0-py2.py3-none-any.whl (16 kB)
# Collecting python-daemon>=2.2.4
#   Downloading python_daemon-2.3.0-py2.py3-none-any.whl (35 kB)
# Collecting pendulum>=2.0
#   Downloading pendulum-2.1.2-cp39-cp39-manylinux1_x86_64.whl (155 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.3/155.3 kB 958.5 kB/s eta 0:00:0000:0100:01
# Collecting cattrs!=1.7.*,~=1.1
#   Downloading cattrs-1.10.0-py3-none-any.whl (29 kB)
# Collecting flask-session<=0.4.0,>=0.3.1
#   Downloading Flask_Session-0.4.0-py2.py3-none-any.whl (7.5 kB)
# Collecting markupsafe<2.1.0,>=1.1.1
#   Downloading MarkupSafe-2.0.1-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (30 kB)
# Collecting rich>=12.4.1
#   Downloading rich-12.4.4-py3-none-any.whl (232 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 232.0/232.0 kB 2.2 MB/s eta 0:00:00a 0:00:01
# Collecting setproctitle>=1.1.8
#   Downloading setproctitle-1.2.3-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (29 kB)
# Collecting deprecated>=1.2.13
#   Downloading Deprecated-1.2.13-py2.py3-none-any.whl (9.6 kB)
# Collecting flask-login<0.5,>=0.3
#   Downloading Flask-Login-0.4.1.tar.gz (14 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: blinker in /opt/conda/lib/python3.9/site-packages (from apache-airflow) (1.4)
# Requirement already satisfied: psutil>=4.2.0 in /opt/conda/lib/python3.9/site-packages (from apache-airflow) (5.9.1)
# Collecting colorlog<5.0,>=4.0.2
#   Downloading colorlog-4.8.0-py2.py3-none-any.whl (10 kB)
# Collecting unicodecsv>=0.14.1
#   Downloading unicodecsv-0.14.1.tar.gz (10 kB)
#   Preparing metadata (setup.py) ... done
# Collecting flask-caching<2.0.0,>=1.5.0
#   Downloading Flask_Caching-1.11.1-py3-none-any.whl (29 kB)
# Collecting lazy-object-proxy
#   Downloading lazy_object_proxy-1.7.1-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.1/61.1 kB 156.5 kB/s eta 0:00:00a 0:00:01
# Collecting connexion[flask,swagger-ui]>=2.10.0
#   Downloading connexion-2.13.1-py2.py3-none-any.whl (95 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 95.1/95.1 kB 406.3 kB/s eta 0:00:00 0:00:01
# Collecting cron-descriptor>=1.2.24
#   Downloading cron_descriptor-1.2.24.tar.gz (22 kB)
#   Preparing metadata (setup.py) ... done
# Collecting graphviz>=0.12
#   Downloading graphviz-0.20-py3-none-any.whl (46 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.0/47.0 kB 194.6 kB/s eta 0:00:00a 0:00:01
# Collecting python-nvd3>=0.15.0
#   Downloading python-nvd3-0.15.0.tar.gz (31 kB)
#   Preparing metadata (setup.py) ... done
# Collecting flask-appbuilder==3.4.5
#   Downloading Flask_AppBuilder-3.4.5-py3-none-any.whl (1.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 498.9 kB/s eta 0:00:0000:0100:01
# Collecting Flask-Babel<3,>=1
#   Downloading Flask_Babel-2.0.0-py3-none-any.whl (9.3 kB)
# Collecting marshmallow<4,>=3
#   Downloading marshmallow-3.16.0-py3-none-any.whl (47 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.9/47.9 kB 430.6 kB/s eta 0:00:00a 0:00:01
# Collecting prison<1.0.0,>=0.2.1
#   Downloading prison-0.2.1-py2.py3-none-any.whl (5.8 kB)
# Collecting sqlalchemy-utils<1,>=0.32.21
#   Downloading SQLAlchemy_Utils-0.38.2-py3-none-any.whl (100 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.2/100.2 kB 792.0 kB/s eta 0:00:00a 0:00:01
# Collecting apispec[yaml]<4,>=3.3
#   Downloading apispec-3.3.2-py2.py3-none-any.whl (27 kB)
# Collecting Flask-JWT-Extended<4,>=3.18
#   Downloading Flask-JWT-Extended-3.25.1.tar.gz (32 kB)
#   Preparing metadata (setup.py) ... done
# Collecting marshmallow-sqlalchemy<0.27.0,>=0.22.0
#   Downloading marshmallow_sqlalchemy-0.26.1-py2.py3-none-any.whl (15 kB)
# Collecting Flask-SQLAlchemy<3,>=2.4
#   Downloading Flask_SQLAlchemy-2.5.1-py2.py3-none-any.whl (17 kB)
# Collecting WTForms<3.0.0
#   Downloading WTForms-2.3.3-py2.py3-none-any.whl (169 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 169.1/169.1 kB 217.0 kB/s eta 0:00:00a 0:00:01
# Collecting PyJWT<2.0.0,>=1.7.1
#   Downloading PyJWT-1.7.1-py2.py3-none-any.whl (18 kB)
# Collecting Flask-OpenID<2,>=1.2.5
#   Downloading Flask_OpenID-1.3.0-py3-none-any.whl (9.3 kB)
# Collecting marshmallow-enum<2,>=1.5.1
#   Downloading marshmallow_enum-1.5.1-py2.py3-none-any.whl (4.2 kB)
# Collecting click<9,>=6.7
#   Downloading click-8.1.3-py3-none-any.whl (96 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.6/96.6 kB 3.2 MB/s eta 0:00:00
# Collecting email-validator<2,>=1.0.5
#   Downloading email_validator-1.2.1-py2.py3-none-any.whl (22 kB)
# Requirement already satisfied: colorama<1,>=0.3.9 in /opt/conda/lib/python3.9/site-packages (from flask-appbuilder==3.4.5->apache-airflow) (0.4.4)
# Requirement already satisfied: Mako in /opt/conda/lib/python3.9/site-packages (from alembic<2.0,>=1.5.1->apache-airflow) (1.2.0)
# Collecting clickclick<21,>=1.2
#   Downloading clickclick-20.10.2-py2.py3-none-any.whl (7.4 kB)
# Requirement already satisfied: requests<3,>=2.9.1 in /opt/conda/lib/python3.9/site-packages (from connexion[flask,swagger-ui]>=2.10.0->apache-airflow) (2.27.1)
# Collecting PyYAML<7,>=5.1
#   Downloading PyYAML-6.0-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (661 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 661.8/661.8 kB 2.2 MB/s eta 0:00:00a 0:00:01
# Collecting inflection<0.6,>=0.3.1
#   Downloading inflection-0.5.1-py2.py3-none-any.whl (9.5 kB)
# Collecting swagger-ui-bundle<0.1,>=0.0.2
#   Downloading swagger_ui_bundle-0.0.9-py3-none-any.whl (6.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.2/6.2 MB 1.6 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: cffi>=1.12 in /opt/conda/lib/python3.9/site-packages (from cryptography>=0.9.3->apache-airflow) (1.15.0)
# Collecting wrapt<2,>=1.10
#   Downloading wrapt-1.14.1-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (77 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.8/77.8 kB 2.3 MB/s eta 0:00:00a 0:00:01
# Collecting jinja2<3.1,>=2.10.1
#   Downloading Jinja2-2.11.3-py2.py3-none-any.whl (125 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 125.7/125.7 kB 146.8 kB/s eta 0:00:0000:0100:01
# Collecting click<9,>=6.7
#   Downloading click-7.1.2-py2.py3-none-any.whl (82 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.8/82.8 kB 508.4 kB/s eta 0:00:000:01
# Collecting cachelib
#   Downloading cachelib-0.7.0-py3-none-any.whl (15 kB)
# Requirement already satisfied: setuptools>=3.0 in /opt/conda/lib/python3.9/site-packages (from gunicorn>=20.1.0->apache-airflow) (62.3.2)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /opt/conda/lib/python3.9/site-packages (from jsonschema<5.0,>=3.2.0->apache-airflow) (0.18.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /opt/conda/lib/python3.9/site-packages (from markdown>=3.0->apache-airflow) (4.11.4)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.9/site-packages (from packaging>=14.0->apache-airflow) (3.0.9)
# Collecting pytzdata>=2020.1
#   Downloading pytzdata-2020.1-py2.py3-none-any.whl (489 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 490.0/490.0 kB 1.2 MB/s eta 0:00:00a 0:00:01
# Collecting docutils
#   Downloading docutils-0.18.1-py2.py3-none-any.whl (570 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 570.0/570.0 kB 1.9 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.9/site-packages (from python-dateutil>=2.3->apache-airflow) (1.16.0)
# Collecting text-unidecode>=1.3
#   Downloading text_unidecode-1.3-py2.py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.2/78.2 kB 1.4 MB/s eta 0:00:00a 0:00:01
# Collecting commonmark<0.10.0,>=0.9.0
#   Downloading commonmark-0.9.1-py2.py3-none-any.whl (51 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.1/51.1 kB 182.7 kB/s eta 0:00:00a 0:00:00
# Requirement already satisfied: greenlet!=0.4.17 in /opt/conda/lib/python3.9/site-packages (from sqlalchemy<1.4.10,>=1.4->apache-airflow) (1.1.2)
# Collecting httpcore<0.16.0,>=0.15.0
#   Downloading httpcore-0.15.0-py3-none-any.whl (68 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.4/68.4 kB 367.5 kB/s eta 0:00:00 0:00:01
# Collecting rfc3986[idna2008]<2,>=1.3
#   Downloading rfc3986-1.5.0-py2.py3-none-any.whl (31 kB)
# Requirement already satisfied: sniffio in /opt/conda/lib/python3.9/site-packages (from httpx->apache-airflow) (1.2.0)
# Requirement already satisfied: certifi in /opt/conda/lib/python3.9/site-packages (from httpx->apache-airflow) (2022.5.18.1)
# Requirement already satisfied: pycparser in /opt/conda/lib/python3.9/site-packages (from cffi>=1.12->cryptography>=0.9.3->apache-airflow) (2.21)
# Collecting dnspython>=1.15.0
#   Downloading dnspython-2.2.1-py3-none-any.whl (269 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 269.1/269.1 kB 1.1 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: idna>=2.0.0 in /opt/conda/lib/python3.9/site-packages (from email-validator<2,>=1.0.5->flask-appbuilder==3.4.5->apache-airflow) (3.3)
# Requirement already satisfied: Babel>=2.3 in /opt/conda/lib/python3.9/site-packages (from Flask-Babel<3,>=1->flask-appbuilder==3.4.5->apache-airflow) (2.10.1)
# Requirement already satisfied: pytz in /opt/conda/lib/python3.9/site-packages (from Flask-Babel<3,>=1->flask-appbuilder==3.4.5->apache-airflow) (2022.1)
# Collecting python3-openid>=2.0
#   Downloading python3_openid-3.2.0-py3-none-any.whl (133 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.7/133.7 kB 482.6 kB/s eta 0:00:00a 0:00:01
# Collecting h11<0.13,>=0.11
#   Downloading h11-0.12.0-py3-none-any.whl (54 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.9/54.9 kB 2.1 MB/s eta 0:00:00
# Requirement already satisfied: anyio==3.* in /opt/conda/lib/python3.9/site-packages (from httpcore<0.16.0,>=0.15.0->httpx->apache-airflow) (3.6.1)
# Requirement already satisfied: zipp>=0.5 in /opt/conda/lib/python3.9/site-packages (from importlib-metadata>=4.4->markdown>=3.0->apache-airflow) (3.8.0)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /opt/conda/lib/python3.9/site-packages (from requests<3,>=2.9.1->connexion[flask,swagger-ui]>=2.10.0->apache-airflow) (2.0.12)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/conda/lib/python3.9/site-packages (from requests<3,>=2.9.1->connexion[flask,swagger-ui]>=2.10.0->apache-airflow) (1.26.9)
# Requirement already satisfied: defusedxml in /opt/conda/lib/python3.9/site-packages (from python3-openid>=2.0->Flask-OpenID<2,>=1.2.5->flask-appbuilder==3.4.5->apache-airflow) (0.7.1)
# Building wheels for collected packages: cron-descriptor, flask-login, python-nvd3, termcolor, unicodecsv, Flask-JWT-Extended
#   Building wheel for cron-descriptor (setup.py) ... done
#   Created wheel for cron-descriptor: filename=cron_descriptor-1.2.24-py3-none-any.whl size=37767 sha256=1c0ddb4391f380ee2f01ddd62ba992d2e3f66676449a6092d952b9050b03cfaf
#   Stored in directory: /home/jovyan/.cache/pip/wheels/0d/d1/e7/4442702da1320037576d20456a6adb7abb2acf2eeb7f9f075d
#   Building wheel for flask-login (setup.py) ... done
#   Created wheel for flask-login: filename=Flask_Login-0.4.1-py2.py3-none-any.whl size=15951 sha256=e56904dc688f072ec30480ec15e863b29aea4c5a63ad48c0ce93c7160bf18636
#   Stored in directory: /home/jovyan/.cache/pip/wheels/0a/95/f9/1b9375cf1e05631591d41a65a730b7ec1f8e05af6db29bb271
#   Building wheel for python-nvd3 (setup.py) ... done
#   Created wheel for python-nvd3: filename=python_nvd3-0.15.0-py3-none-any.whl size=38149 sha256=5851e7823c6061d3faf4b9acc4bac58b86b15e24e2d305652bed56ea7a8dc45b
#   Stored in directory: /home/jovyan/.cache/pip/wheels/60/e8/21/19a3dcfe90e8895952857d42152663fafc5a90d87d3dfe5f58
#   Building wheel for termcolor (setup.py) ... done
#   Created wheel for termcolor: filename=termcolor-1.1.0-py3-none-any.whl size=4832 sha256=698e0f258ed545e265204dbfb07b784ce1d39d8d7b6ca35dcac2d5b2f5d70d69
#   Stored in directory: /home/jovyan/.cache/pip/wheels/b6/0d/90/0d1bbd99855f99cb2f6c2e5ff96f8023fad8ec367695f7d72d
#   Building wheel for unicodecsv (setup.py) ... done
#   Created wheel for unicodecsv: filename=unicodecsv-0.14.1-py3-none-any.whl size=10746 sha256=ff1c09301fa0d45b9dc9cbce3c636f163951315071b38053177919efa7ca1d9b
#   Stored in directory: /home/jovyan/.cache/pip/wheels/d8/c8/27/b237d3378d5c9ed25c2c63d9af1b3d5ccb99934f3dd030de87
#   Building wheel for Flask-JWT-Extended (setup.py) ... done
#   Created wheel for Flask-JWT-Extended: filename=Flask_JWT_Extended-3.25.1-py2.py3-none-any.whl size=21611 sha256=08f1b6f4b68bd7714abf5b1083be661f34a5f80cbbe1ba913e6f229dcb3bb2ea
#   Stored in directory: /home/jovyan/.cache/pip/wheels/89/29/80/cacbcaec7c90fb2c53b5b385a3bbef89de3df159f097b26012
# Successfully built cron-descriptor flask-login python-nvd3 termcolor unicodecsv Flask-JWT-Extended
# Installing collected packages: unicodecsv, text-unidecode, termcolor, tabulate, rfc3986, PyJWT, lockfile, cron-descriptor, commonmark, colorlog, wrapt, werkzeug, typing-extensions, tenacity, sqlalchemy, setproctitle, rich, PyYAML, pytzdata, python3-openid, python-slugify, prison, pluggy, pathspec, markupsafe, lazy-object-proxy, itsdangerous, inflection, h11, gunicorn, graphviz, docutils, dnspython, dill, click, cachelib, attrs, argcomplete, apispec, apache-airflow-providers-sqlite, apache-airflow-providers-imap, apache-airflow-providers-ftp, WTForms, sqlalchemy-utils, sqlalchemy-jsonfield, python-daemon, pendulum, marshmallow, markdown, jinja2, httpcore, email-validator, deprecated, croniter, clickclick, cattrs, apache-airflow-providers-http, swagger-ui-bundle, python-nvd3, marshmallow-sqlalchemy, marshmallow-oneofschema, marshmallow-enum, httpx, flask, flask-wtf, Flask-SQLAlchemy, flask-session, Flask-OpenID, flask-login, Flask-JWT-Extended, flask-caching, Flask-Babel, connexion, flask-appbuilder, apache-airflow
#   Attempting uninstall: PyJWT
#     Found existing installation: PyJWT 2.4.0
#     Uninstalling PyJWT-2.4.0:
#       Successfully uninstalled PyJWT-2.4.0
#   Attempting uninstall: sqlalchemy
#     Found existing installation: SQLAlchemy 1.4.36
#     Uninstalling SQLAlchemy-1.4.36:
#       Successfully uninstalled SQLAlchemy-1.4.36
#   Attempting uninstall: markupsafe
#     Found existing installation: MarkupSafe 2.1.1
#     Uninstalling MarkupSafe-2.1.1:
#       Successfully uninstalled MarkupSafe-2.1.1
#   Attempting uninstall: attrs
#     Found existing installation: attrs 21.4.0
#     Uninstalling attrs-21.4.0:
#       Successfully uninstalled attrs-21.4.0
#   Attempting uninstall: jinja2
#     Found existing installation: Jinja2 3.1.2
#     Uninstalling Jinja2-3.1.2:
#       Successfully uninstalled Jinja2-3.1.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# nbconvert 6.5.0 requires jinja2>=3.0, but you have jinja2 2.11.3 which is incompatible.
# jupyterlab-server 2.14.0 requires jinja2>=3.0.3, but you have jinja2 2.11.3 which is incompatible.
# Successfully installed Flask-Babel-2.0.0 Flask-JWT-Extended-3.25.1 Flask-OpenID-1.3.0 Flask-SQLAlchemy-2.5.1 PyJWT-1.7.1 PyYAML-6.0 WTForms-2.3.3 apache-airflow-2.3.2 apache-airflow-providers-ftp-2.1.2 apache-airflow-providers-http-2.1.2 apache-airflow-providers-imap-2.2.3 apache-airflow-providers-sqlite-2.1.3 apispec-3.3.2 argcomplete-2.0.0 attrs-20.3.0 cachelib-0.7.0 cattrs-1.10.0 click-7.1.2 clickclick-20.10.2 colorlog-4.8.0 commonmark-0.9.1 connexion-2.13.1 cron-descriptor-1.2.24 croniter-1.3.5 deprecated-1.2.13 dill-0.3.5.1 dnspython-2.2.1 docutils-0.18.1 email-validator-1.2.1 flask-1.1.4 flask-appbuilder-3.4.5 flask-caching-1.11.1 flask-login-0.4.1 flask-session-0.4.0 flask-wtf-0.14.3 graphviz-0.20 gunicorn-20.1.0 h11-0.12.0 httpcore-0.15.0 httpx-0.23.0 inflection-0.5.1 itsdangerous-1.1.0 jinja2-2.11.3 lazy-object-proxy-1.7.1 lockfile-0.12.2 markdown-3.3.7 markupsafe-2.0.1 marshmallow-3.16.0 marshmallow-enum-1.5.1 marshmallow-oneofschema-3.0.1 marshmallow-sqlalchemy-0.26.1 pathspec-0.9.0 pendulum-2.1.2 pluggy-1.0.0 prison-0.2.1 python-daemon-2.3.0 python-nvd3-0.15.0 python-slugify-6.1.2 python3-openid-3.2.0 pytzdata-2020.1 rfc3986-1.5.0 rich-12.4.4 setproctitle-1.2.3 sqlalchemy-1.4.9 sqlalchemy-jsonfield-1.0.0 sqlalchemy-utils-0.38.2 swagger-ui-bundle-0.0.9 tabulate-0.8.9 tenacity-8.0.1 termcolor-1.1.0 text-unidecode-1.3 typing-extensions-4.2.0 unicodecsv-0.14.1 werkzeug-1.0.1 wrapt-1.14.1
# /tmp/ipykernel_81/3017525675.py:5 DeprecationWarning: This module is deprecated. Please use `airflow.operators.bash`.
# /tmp/ipykernel_81/3017525675.py:6 DeprecationWarning: This module is deprecated. Please use `airflow.operators.python`.

# %%
def Get_DF_i(Day):
        import pandas as pd
        DF_i=None
        try: 
            URL_Day=f'https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/{Day}.csv'
            DF_day=pd.read_csv(URL_Day)
            DF_day['Day']=Day
            cond=(DF_day.Country_Region=='United Kingdom')
            Selec_columns=['Day','Country_Region', 'Last_Update',
                  'Lat', 'Long_', 'Confirmed', 'Deaths', 'Recovered', 'Active',
                  'Combined_Key', 'Incident_Rate', 'Case_Fatality_Ratio']
            DF_i=DF_day[cond][Selec_columns].reset_index(drop=True)
        except:
            print(f'{Day} is not available!')
            pass
        return DF_i

def Create_data():
        import pandas as pd
        List_of_Days=[]
        import datetime
        for i in range(1,145):
                Previous_Date = datetime.datetime.today() - datetime.timedelta(days=145-i)
                if (Previous_Date.day >9):
                    if (Previous_Date.month >9):
                          List_of_Days.append(f'{Previous_Date.month}-{Previous_Date.day}-{Previous_Date.year}')
                    else:
                          List_of_Days.append(f'0{Previous_Date.month}-{Previous_Date.day}-{Previous_Date.year}')
                else:
                    if (Previous_Date.month >9):
                          List_of_Days.append(f'{Previous_Date.month}-0{Previous_Date.day}-{Previous_Date.year}')
                    else:
                          List_of_Days.append(f'0{Previous_Date.month}-0{Previous_Date.day}-{Previous_Date.year}')
            
        DF_all=[]
        for Day in List_of_Days:
            DF_all.append(Get_DF_i(Day))
            
        DF_UK=pd.concat(DF_all).reset_index(drop=True)
        DF_UK['Last_Update']=pd.to_datetime(DF_UK.Last_Update, infer_datetime_format=True)  
        DF_UK['Day']=pd.to_datetime(DF_UK.Day, infer_datetime_format=True)  
        DF_UK['Case_Fatality_Ratio']=DF_UK['Case_Fatality_Ratio'].astype(float)
        DF_UK.set_index('Day', inplace=True)
        DF_UK.to_csv('/opt/airflow/data/DF_UK.csv')

def MinMaxScaler():
        import pandas as pd
        import sklearn
        from sklearn.preprocessing import MinMaxScaler
        DF_UK = pd.read_csv('/opt/airflow/data/DF_UK.csv', parse_dates=['Last_Update'])
        DF_UK['Day']=DF_UK.Day
        DF_UK.set_index('Day', inplace=True)
        min_max_scaler = MinMaxScaler()
        DF_UK_u=DF_UK.copy()
        Select_Columns=['Confirmed','Deaths', 'Recovered', 'Active','Case_Fatality_Ratio']
        DF_UK_2=DF_UK_u[Select_Columns]
        DF_UK_3 = pd.DataFrame(min_max_scaler.fit_transform(DF_UK_2[Select_Columns]),columns=Select_Columns)
        DF_UK_3['Day']=DF_UK_u.index
        DF_UK_3.set_index('Day', inplace=True)
        DF_UK_3.to_csv('/opt/airflow/data/DF_UK_Scaled.csv')

def Plotting():
        import pandas as pd 
        import matplotlib.pyplot as plt
        DF_UK_u_3 = pd.read_csv('/opt/airflow/data/DF_UK_Scaled.csv', parse_dates=['Day'])
        DF_UK_u_3.set_index('Day', inplace=True) 
        Select_Columns=['Confirmed','Deaths', 'Recovered', 'Active','Case_Fatality_Ratio']
        DF_UK_u_3[Select_Columns].plot(figsize=(30,20))
        plt.savefig('/opt/airflow/output/UK_scoring_report.png')
    

def CSV_to_Postgres():
        import sqlalchemy
        from sqlalchemy import create_engine
        import pandas as pd

        DF_UK_Scaled = pd.read_csv('/opt/airflow/data/UK_scoring_report.csv', parse_dates=['Day'])
        DF_UK_Scaled.set_index('Day', inplace=True)

        host="localhost"
        database="testDB"
        user="me"
        password="1234"
        port='5432'
        engine = create_engine(f'postgresql://{user}:{password}@{host}:{port}/{database}')
        DF_UK_Scaled.to_sql('UK_scoring_report', engine,if_exists='replace',index=False)    

 
 
default_args = {
    'owner': 'Huda',
    'start_date': dt.datetime(2022, 5, 30),
    'retries': 1,
    'retry_delay': dt.timedelta(minutes=1),
}
 
with DAG('UK_COVID19_dag',
         default_args=default_args,
         schedule_interval=timedelta(days=1),  
         catchup=False,     
         ) as dag:
    
    Install_dependecies = BashOperator(task_id='Install_dependecies',bash_command='pip install sklearn matplotlib')   
    Extract_Data = PythonOperator(task_id='Extract_UK_Data', python_callable=Create_data)
    Scaled_Data = PythonOperator(task_id='Scale_UK_Data', python_callable=MinMaxScaler)
    Ploting_Data = PythonOperator(task_id='Plot_UK_Data', python_callable=Plotting)
    Push_Data_to_Postgres = PythonOperator(task_id='Push_Data_to_Postgres', python_callable=CSV_to_Postgres)

 
 
 

Install_dependecies >> Extract_Data >> Scaled_Data >> Ploting_Data >> Push_Data_to_Postgres
# Out:
# <Task(PythonOperator): Push_Data_to_Postgres>
